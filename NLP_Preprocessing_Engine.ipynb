# %%
# NLP Preprocessing Engine
## Data Science Internship Assignment – Feb 2026

# %%
## Task 1: Conceptual Understanding

1. Love vs love:
Both are treated as different tokens due to case sensitivity...

2. Stopwords:
If not removed, they add noise...

3. Harmful cases:
- Sentiment analysis
- Question answering

4. Stemming vs Lemmatization:
Stemming cuts words, lemmatization gives meaningful base word...

# %%
#Task 2: Preprocessing Function
import re
from collections import Counter
import numpy as np

# %%
def preprocess_text(text):
    if not isinstance(text, str) or text.strip() == "":
        return [], ""

    text = re.sub(r"http\S+|www\S+|https\S+", "", text)
    text = re.sub(r"\S+@\S+", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r"(.)\1{2,}", r"\1", text)
    text = re.sub(r"[^\w\s]", "", text)

    text = text.lower()
    text = re.sub(r"\s+", " ", text).strip()

    tokens = text.split()

    cleaned_tokens = [
        word for word in tokens if len(word) > 2 or word in ["no", "not"]
    ]

    return cleaned_tokens, " ".join(cleaned_tokens)

# %%
#Task 3: Stress Testing
test_sentences = [
    "Get 100% FREE access now!!!",
    "I absolutely looooved this product 😍😍",
    "Worst service ever... 0/10",
    "Call me at 9876543210",
    "This is THE best course!!!",
    "Visit https://openai.com now!",
    "Nooooo this is baaad!!!",
    "OK OK OK I got it",
    "Win $$$ now!!! Limited offer!!!",
    "I am not happy with this"
]

results = []

for text in test_sentences:
    tokens, cleaned = preprocess_text(text)
    print("Original:", text)
    print("Tokens:", tokens)
    print("Cleaned:", cleaned)
    print("-"*50)
    results.append(tokens)
# Out:
# Original: Get 100% FREE access now!!!
# Tokens: ['get', 'free', 'access', 'now']
# Cleaned: get free access now
# --------------------------------------------------
# Original: I absolutely looooved this product 😍😍
# Tokens: ['absolutely', 'loved', 'this', 'product']
# Cleaned: absolutely loved this product
# --------------------------------------------------
# Original: Worst service ever... 0/10
# Tokens: ['worst', 'service', 'ever']
# Cleaned: worst service ever
# --------------------------------------------------
# Original: Call me at 9876543210
# Tokens: ['call']
# Cleaned: call
# --------------------------------------------------
# Original: This is THE best course!!!
# Tokens: ['this', 'the', 'best', 'course']
# Cleaned: this the best course
# --------------------------------------------------
# Original: Visit https://openai.com now!
# Tokens: ['visit', 'now']
# Cleaned: visit now
# --------------------------------------------------
# Original: Nooooo this is baaad!!!
# ...

# %%
#Task 4: Token Analytics
for i, tokens in enumerate(results):
    if len(tokens) == 0:
        print(f"Sentence {i+1}: No tokens")
        continue

    total = len(tokens)
    unique = len(set(tokens))
    avg_len = np.mean([len(word) for word in tokens])

    print(f"Sentence {i+1}: Total={total}, Unique={unique}, Avg Length={avg_len:.2f}")
# Out:
# Sentence 1: Total=4, Unique=4, Avg Length=4.00
# Sentence 2: Total=4, Unique=4, Avg Length=6.50
# Sentence 3: Total=3, Unique=3, Avg Length=5.33
# Sentence 4: Total=1, Unique=1, Avg Length=4.00
# Sentence 5: Total=4, Unique=4, Avg Length=4.25
# Sentence 6: Total=2, Unique=2, Avg Length=4.00
# Sentence 7: Total=3, Unique=3, Avg Length=3.00
# Sentence 8: Total=1, Unique=1, Avg Length=3.00
# Sentence 9: Total=4, Unique=4, Avg Length=4.50
# Sentence 10: Total=4, Unique=4, Avg Length=4.00

# %%
## Analysis

Most noisy sentence:
Get 100% FREE access now!!!

Most meaningful:
I am not happy with this

# %%
#Task 5: Frequency Analysis
all_tokens = [word for tokens in results for word in tokens]

counter = Counter(all_tokens)

print(counter.most_common(10))
print(sorted(counter.items(), key=lambda x: x[1])[:5])
# Out:
# [('this', 4), ('now', 3), ('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1), ('product', 1), ('worst', 1), ('service', 1)]
# [('get', 1), ('free', 1), ('access', 1), ('absolutely', 1), ('loved', 1)]

# %%
#Task 6 full pipleline
result = full_pipeline(test_sentences)

print("All Tokens:")
print(result["tokens"])

print("\nClean Sentences:")
for sent in result["clean_sentences"]:
    print("-", sent)
# Out:
# All Tokens:
# ['get', 'free', 'access', 'now', 'absolutely', 'loved', 'this', 'product', 'worst', 'service', 'ever', 'call', 'this', 'the', 'best', 'course', 'visit', 'now', 'no', 'this', 'bad', 'got', 'win', 'now', 'limited', 'offer', 'not', 'happy', 'with', 'this']
#
# Clean Sentences:
# - get free access now
# - absolutely loved this product
# - worst service ever
# - call
# - this the best course
# - visit now
# - no this bad
# - got
# - win now limited offer
# - not happy with this

# %%
#Task 7: Error Handling
edge_cases = ["", "😍😍😍", "123456"]

for case in edge_cases:
    tokens, cleaned = preprocess_text(case)
    print(case, "->", tokens, "|", cleaned)
# Out:
#  -> [] |
# 😍😍😍 -> [] |
# 123456 -> [] |
